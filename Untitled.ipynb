# %%
import json

# %%
# Opening JSON file
f = open('../../../Downloads/swagger-fixed-160723-2.json')
  
# returns JSON object as 
# a dictionary
api_spec = json.load(f)

# %%
for path in api_spec['paths']:
    print(path)
# Out:
# /accounts/domain
# /accounts/user/{id}
# /accounts/users
# /accounts/{id}
# /accounts/{id}/confidence
# /accounts/{id}/notifications
# /announcements
# /announcements/{id}
# /announcements/{id}/react
# /assignees
# /badges
# /badges/approve
# /badges/approve/{id}
# /badges/assign
# /badges/assign/{assigneeId}/{badgeAssignId}
# /badges/assign/{id}
# /badges/current/{id}
# /categories/{type}
# /config
# /config/all-activities
# /config/{section}
# /config/{section}/activities
# /connectors/datasourceblueprint/{name}
# /connectors/{id}
# /connectors/{id}/datasources
# /customFields
# /customFields/supported-types
# /customFields/{id}
# /dashboards
# /dashboards/items/{id}
# /dashboards/parameters
# /dashboards/parameters/{parameterId}
# /dashboards/reports
# /dashboards/tag/{tag}
# /dashboards/tags/usages
# /dashboards/{dashboardId}
# /dashboards/{dashboardId}/cached/calculate
# /dashboards/{dashboardId}/calculate
# /dashboards/{dashboardId}/clone
# /dashboards/{dashboardId}/items
# ...
